# %%
import json
orgaos_equivalentes = {
    "Casa Civil": [
        "CASA CIVIL"
    ],
    "Controladoria Geral do Município": [
        "CONTROLADORIA GERAL DO MUNICIPIO",
        "Controladoria Geral do Município"
    ],
    "Gabinete do Prefeito": [
        "GABINETE DO PREFEITO"
    ],
    "Secretaria do Governo Municipal": [
        "SECRETARIA DO GOVERNO MUNICIPAL",
        "Secretaria do Governo Municipal"
    ],
    "Secretaria Municipal da Saúde": [
        "SECRETARIA MUNICIPAL DA SAUDE",
        "Secretaria Municipal da Saúde",
        "Fundo Municipal de Saúde"
    ],
    "Secretaria Municipal de Gestão": [
        "SECRETARIA MUNICIPAL DE GESTAO",
        "Secretaria Municipal de Gestão",
        "Secretaria Municipal  de Modernização, Gestão e Desburocratização",
        "Secretaria Municipal de Gestão"
    ],
    "Secretaria Municipal de Habitação": [
        "SECRETARIA MUNICIPAL DE HABITACAO",
        "Secretaria Municipal de Habitação",
        "Fundo Municipal de Saneamento Ambiental e Infraestrutura",
        "Fundo Municipal de Habitação"
    ],
    "Secretaria Municipal de Infraestrutura Urbana e Obras": [
        "SECRETARIA MUNICIPAL DE INFRAESTRUTURA URBANA E OB",
        "Secretaria Municipal de Infraestrutura Urbana e Obras"
    ],
    "Secretaria Municipal de Justiça": [
        "SECRETARIA MUNICIPAL DE JUSTICA",
        "Secretaria Municipal de Justiça"
    ],
    "Secretaria Municipal de Mobilidade e Trânsito": [
        "SECRETARIA MUNICIPAL DE MOBILIDADE E TRANSITO",
        "Secretaria Municipal de Mobilidade e Trânsito",
        "Fundo Municipal de Desenvolvimento de Trânsito"
    ],
    "Secretaria Municipal de Relações Internacionais": [
        "SECRETARIA MUNICIPAL DE RELACOES INTERNACIONAIS",
        "Secretaria Municipal de Relações Internacionais"
    ],
    "Secretaria Municipal de Turismo": [
        "SECRETARIA MUNICIPAL DE TURISMO",
        "Secretaria Municipal de Turismo"
    ],
    "Secretaria Municipal da Pessoa com Deficiência": [
        "SECRETARIA MUNICIPAL DA PESSOA COM DEFICIENCIA",
        "Secretaria Municipal da Pessoa com Deficiência"
    ],
    "Secretaria Municipal das Subprefeituras": [
        "SECRETARIA MUNICIPAL DAS SUBPREFEITURAS",
        "Secretaria Municipal das Subprefeituras"
    ],
    "Secretaria Municipal de Cultura": [
        "SECRETARIA MUNICIPAL DE CULTURA",
        "Secretaria Municipal de Cultura",
        "Fundo Especial de Promoção de Atividades Culturais",
        "Fundo de Proteção do Patrimônio Cultural e Ambiental Paulistano"
    ],
    "Secretaria Municipal de Desenvolvimento Econômico, Trabalho e Turismo": [
        "SECRETARIA MUNICIPAL DE DESENVOLVIMENTO ECONOMICO",
        "Secretaria Municipal de Desenvolvimento Econômico, Trabalho e Turismo",
        "Secretaria Municipal de Desenvolvimento Econômico e Trabalho"
    ],
    "Secretaria Municipal de Direitos Humanos e Cidadania": [
        "SECRETARIA MUNICIPAL DE DIREITOS HUMANOS E CIDADAN",
        "Secretaria Municipal de Direitos Humanos e Cidadania",
        "Fundo Municipal do Idoso",
        "Fundo Municipal dos Direitos da Criança e do Adolescente",
        "Fundo de Abastecimento Alimentar de São Paulo"
    ],
    "Secretaria Municipal de Inovação e Tecnologia": [
        "SECRETARIA MUNICIPAL DE INOVACAO E TECNOLOGIA",
        "Secretaria Municipal de Inovação e Tecnologia"
    ],
    "Procuradoria Geral do Município": [
        "PROCURADORIA GERAL DO MUNICIPIO",
        "Procuradoria Geral do Município",
        "Procuradoria Geral do Município - PGM"
    ],
    "Secretaria Municipal de Assistência e Desenvolvimento Social": [
        "SECRETARIA MUNICIPAL DE ASSIST E DESENV SOCIAL",
        "Secretaria Municipal de Assistência e Desenvolvimento Social",
        "Fundo Municipal de Assistência Social"
    ],
    "Secretaria Municipal de Educação": [
        "SECRETARIA MUNICIPAL DE EDUCACAO",
        "Secretaria Municipal de Educação"
    ],
    "Secretaria Municipal de Esportes e Lazer": [
        "SECRETARIA MUNICIPAL DE ESPORTES E LAZER",
        "Secretaria Municipal de Esportes e Lazer"
    ],
    "Secretaria Municipal de Segurança Urbana": [
        "SECRETARIA MUNICIPAL DE SEGURANCA URBANA",
        "Secretaria Municipal de Segurança Urbana"
    ],
    "Secretaria Municipal de Urbanismo e Licenciamento": [
        "SECRETARIA MUNICIPAL DE URBANISMO E LICENCIAMENTO",
        "Secretaria Municipal de Urbanismo e Licenciamento",
        "Fundo de Desenvolvimento Urbano"
    ],
    "Secretaria Municipal do Verde e do Meio Ambiente": [
        "SECRETARIA MUNICIPAL DO VERDE E DO MEIO AMBIENTE",
        "Secretaria Municipal do Verde e do Meio Ambiente",
        "Fundo Especial do Meio Ambiente e Desenvolvimento Sustentável"
    ],
    "Secretaria Municipal da Fazenda": [
        "SECRETARIA MUNICIPAL DA FAZENDA",
        "Secretaria Municipal da Fazenda",
        "Fundo Municipal de Desenvolvimento Social"
    ],
    "Câmara Municipal de São Paulo": [
        "Câmara Municipal de São Paulo"
    ],
    "Tribunal de Contas do Município de São Paulo": [
        "Tribunal de Contas do Município de São Paulo"
    ],
    "Encargos Gerais do Município": [
        "Encargos Gerais do Município"
    ],
    "Secretaria Municipal de Desenvolvimento Urbano": [
        "Secretaria Municipal de Desenvolvimento Urbano"
    ],
    "Secretaria Executiva de Desestatização e Parcerias": [
        "Secretaria Executiva de Desestatização e Parcerias"
    ],
    "Secretaria Executiva de Projetos Estratégicos": [
        "Secretaria Executiva de Projetos Estratégicos"
    ],
    "Secretaria Executiva de Mudanças Climáticas": [
        "Secretaria Executiva de Mudanças Climáticas"
    ],
    "Fundo Municipal de Iluminação Pública": [
        "Fundo Municipal de Iluminação Pública"
    ],
    "Fundação Paulistana de Educação, Tecnologia e Cultura" : ["Fundação Paulistana de Educação, Tecnologia e Cultura"]
}


with open("padronizacao_orgaos.json", "w", encoding="utf-8") as f:
    json.dump(orgaos_equivalentes, f, ensure_ascii=False, indent=4)

# %%
path_json = '/home/jovyan/work/lucas-ecg/dados_abertos/padronizacao_orgaos.json'
with open(path_json, "r", encoding="utf-8") as f:
    orgaos_padronizados = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 path_json = '/home/jovyan/work/lucas-ecg/dados_abertos/padronizacao_orgaos.json'
# ----> 2 with open(path_json, "r", encoding="utf-8") as f:
#       3     orgaos_padronizados = json.load(f)
#
# File /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/work/lucas-ecg/dados_abertos/padronizacao_orgaos.json'

# %%
orgaos_padronizados
# Out:
# {'Casa Civil': ['CASA CIVIL'],
#  'Controladoria Geral do Município': ['CONTROLADORIA GERAL DO MUNICIPIO',
#   'Controladoria Geral do Município'],
#  'Gabinete do Prefeito': ['GABINETE DO PREFEITO'],
#  'Secretaria do Governo Municipal': ['SECRETARIA DO GOVERNO MUNICIPAL',
#   'Secretaria do Governo Municipal'],
#  'Secretaria Municipal da Saúde': ['SECRETARIA MUNICIPAL DA SAUDE',
#   'Secretaria Municipal da Saúde',
#   'Fundo Municipal de Saúde'],
#  'Secretaria Municipal de Gestão': ['SECRETARIA MUNICIPAL DE GESTAO',
#   'Secretaria Municipal de Gestão',
#   'Secretaria Municipal  de Modernização, Gestão e Desburocratização',
#   'Secretaria Municipal de Gestão'],
#  'Secretaria Municipal de Habitação': ['SECRETARIA MUNICIPAL DE HABITACAO',
#   'Secretaria Municipal de Habitação',
#   'Fundo Municipal de Saneamento Ambiental e Infraestrutura',
#   'Fundo Municipal de Habitação'],
#  'Secretaria Municipal de Infraestrutura Urbana e Obras': ['SECRETARIA MUNICIPAL DE INFRAESTRUTURA URBANA E OB',
#   'Secretaria Municipal de Infraestrutura Urbana e Obras'],
#  'Secretaria Municipal de Justiça': ['SECRETARIA MUNICIPAL DE JUSTICA',
#   'Secretaria Municipal de Justiça'],
#  'Secretaria Municipal de Mobilidade e Trânsito': ['SECRETARIA MUNICIPAL DE MOBILIDADE E TRANSITO',
#   'Secretaria Municipal de Mobilidade e Trânsito',
#   'Fundo Municipal de Desenvolvimento de Trânsito'],
#  'Secretaria Municipal de Relações Internacionais': ['SECRETARIA MUNICIPAL DE RELACOES INTERNACIONAIS',
#   'Secretaria Municipal de Relações Internacionais'],
#  'Secretaria Municipal de Turismo': ['SECRETARIA MUNICIPAL DE TURISMO',
#   'Secretaria Municipal de Turismo'],
#  'Secretaria Municipal da Pessoa com Deficiência': ['SECRETARIA MUNICIPAL DA PESSOA COM DEFICIENCIA',
#   'Secretaria Municipal da Pessoa com Deficiência'],
#  'Secretaria Municipal das Subprefeituras': ['SECRETARIA MUNICIPAL DAS SUBPREFEITURAS',
#   'Secretaria Municipal das Subprefeituras'],
#  'Secretaria Municipal de Cultura': ['SECRETARIA MUNICIPAL DE CULTURA',
#   'Secretaria Municipal de Cultura',
#   'Fundo Especial de Promoção de Atividades Culturais',
#   'Fundo de Proteção do Patrimônio Cultural e Ambiental Paulistano'],
#  'Secretaria Municipal de Desenvolvimento Econômico, Trabalho e Turismo': ['SECRETARIA MUNICIPAL DE DESENVOLVIMENTO ECONOMICO',
#   'Secretaria Municipal de Desenvolvimento Econômico, Trabalho e Turismo',
#   'Secretaria Municipal de Desenvolvimento Econômico e Trabalho'],
#  'Secretaria Municipal de Direitos Humanos e Cidadania': ['SECRETARIA MUNICIPAL DE DIREITOS HUMANOS E CIDADAN',
#   'Secretaria Municipal de Direitos Humanos e Cidadania',
#   'Fundo Municipal do Idoso',
#   'Fundo Municipal dos Direitos da Criança e do Adolescente',
#   'Fundo de Abastecimento Alimentar de São Paulo'],
#  'Secretaria Municipal de Inovação e Tecnologia': ['SECRETARIA MUNICIPAL DE INOVACAO E TECNOLOGIA',
#   'Secretaria Municipal de Inovação e Tecnologia'],
#  'Procuradoria Geral do Município': ['PROCURADORIA GERAL DO MUNICIPIO',
#   'Procuradoria Geral do Município',
#   'Procuradoria Geral do Município - PGM'],
#  'Secretaria Municipal de Assistência e Desenvolvimento Social': ['SECRETARIA MUNICIPAL DE ASSIST E DESENV SOCIAL',
#   'Secretaria Municipal de Assistência e Desenvolvimento Social',
#   'Fundo Municipal de Assistência Social'],
#  'Secretaria Municipal de Educação': ['SECRETARIA MUNICIPAL DE EDUCACAO',
#   'Secretaria Municipal de Educação'],
#  'Secretaria Municipal de Esportes e Lazer': ['SECRETARIA MUNICIPAL DE ESPORTES E LAZER',
#   'Secretaria Municipal de Esportes e Lazer'],
#  'Secretaria Municipal de Segurança Urbana': ['SECRETARIA MUNICIPAL DE SEGURANCA URBANA',
#   'Secretaria Municipal de Segurança Urbana'],
#  'Secretaria Municipal de Urbanismo e Licenciamento': ['SECRETARIA MUNICIPAL DE URBANISMO E LICENCIAMENTO',
#   'Secretaria Municipal de Urbanismo e Licenciamento',
#   'Fundo de Desenvolvimento Urbano'],
#  'Secretaria Municipal do Verde e do Meio Ambiente': ['SECRETARIA MUNICIPAL DO VERDE E DO MEIO AMBIENTE',
#   'Secretaria Municipal do Verde e do Meio Ambiente',
#   'Fundo Especial do Meio Ambiente e Desenvolvimento Sustentável'],
#  'Secretaria Municipal da Fazenda': ['SECRETARIA MUNICIPAL DA FAZENDA',
#   'Secretaria Municipal da Fazenda',
#   'Fundo Municipal de Desenvolvimento Social'],
#  'Câmara Municipal de São Paulo': ['Câmara Municipal de São Paulo'],
#  'Tribunal de Contas do Município de São Paulo': ['Tribunal de Contas do Município de São Paulo'],
#  'Encargos Gerais do Município': ['Encargos Gerais do Município'],
#  'Secretaria Municipal de Desenvolvimento Urbano': ['Secretaria Municipal de Desenvolvimento Urbano'],
#  'Secretaria Executiva de Desestatização e Parcerias': ['Secretaria Executiva de Desestatização e Parcerias'],
#  'Secretaria Executiva de Projetos Estratégicos': ['Secretaria Executiva de Projetos Estratégicos'],
#  'Secretaria Executiva de Mudanças Climáticas': ['Secretaria Executiva de Mudanças Climáticas'],
#  'Fundo Municipal de Iluminação Pública': ['Fundo Municipal de Iluminação Pública'],
#  'Fundação Paulistana de Educação, Tecnologia e Cultura': ['Fundação Paulistana de Educação, Tecnologia e Cultura']}
